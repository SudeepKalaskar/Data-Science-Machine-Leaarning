# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data = make_classification(n_samples=1000, n_classes=3, n_informative=6)

# %%
X = data[0]
y = data[1]

# %%
X[:10]
# Out:
# array([[ 2.15368951e+00, -1.44418235e+00, -5.69044010e-01,
#         -3.48614007e-01, -9.69102551e-01, -1.70808136e+00,
#         -3.73040673e+00, -6.69902516e-01,  3.35682762e-01,
#          8.82274114e-01, -1.15961491e-01, -2.77601751e+00,
#          2.59443690e+00, -2.72366108e-01, -1.25638939e-01,
#         -6.42936494e-01, -9.72728463e-01,  6.13913851e-01,
#          1.29320357e-01,  3.61339723e-01],
#        [ 2.86342706e+00, -1.72904685e+00, -1.54653319e-01,
#         -5.49600854e-01,  1.33944747e+00, -2.03433942e-01,
#         -3.99666952e+00,  2.17112813e-01,  3.37000634e-01,
#         -1.01446947e+00, -1.35968491e+00,  8.64554747e-01,
#          1.07700296e+00,  6.92668552e-01, -4.92697971e-01,
#         -1.10766763e+00,  3.71873137e-01, -1.97027719e+00,
#          1.69016930e+00, -9.10426081e-01],
#        [ 2.05573237e+00, -3.63137459e-01, -2.45610666e+00,
#          7.16003077e-01, -4.89898332e-01,  2.71703074e-01,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X[y==0,0], X[y==0,2])
plt.scatter(X[y==1,0], X[y==1,2])
plt.scatter(X[y==2,0], X[y==2,2])

# %%
model = RandomForestClassifier(n_estimators=100, n_jobs=1, criterion="entropy")

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=.25, random_state=43)

# %%
model.fit(X_tr, y_tr)
# Out:
# RandomForestClassifier(criterion='entropy', n_jobs=1)

# %%
model.score(X_tr, y_tr)
# Out:
# 1.0

# %%
y_pr = model.predict(X_te)

# %%
accuracy_score(y_te, y_pr)
# Out:
# 0.748

# %%
conf = confusion_matrix(y_te, y_pr)
conf
# Out:
# array([[70, 16,  7],
#        [16, 56, 11],
#        [ 8,  5, 61]], dtype=int64)

# %%
print(classification_report(y_te, y_pr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75        93
#            1       0.73      0.67      0.70        83
#            2       0.77      0.82      0.80        74
#
#     accuracy                           0.75       250
#    macro avg       0.75      0.75      0.75       250
# weighted avg       0.75      0.75      0.75       250

# %%
import seaborn as sns

# %%
sns.heatmap(conf, annot=True)
# Out:
# <Axes: >
